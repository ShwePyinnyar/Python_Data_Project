# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt
import ast
import seaborn as sns

dataset=load_dataset('lukebarousse/data_jobs')
df=dataset['train'].to_pandas()

df.job_posted_date=pd.to_datetime(df.job_posted_date)
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x )

# %%
df_da_US = df[(df['job_title_short'] == 'Data Analyst') & (df['job_country']=='United States')].copy()

# %%
df_da_US['month'] = df_da_US.job_posted_date.dt.month
df_da_US.sample()
# Out:
#        job_title_short             job_title  job_location           job_via  \
# 119769    Data Analyst  Field Data Collector  Syracuse, NY  via ZipRecruiter
#
#        job_schedule_type  job_work_from_home          search_location  \
# 119769         Full-time               False  New York, United States
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 119769 2023-11-21 08:00:36                   True                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 119769  United States        hour              NaN        24.459999
#
#                              company_name job_skills job_type_skills  month
# 119769  NORC at the University of Chicago       None            None     11

# %%
df_da_US_explode = df_da_US.explode('job_skills')
df_da_US_explode
# Out:
#        job_title_short                                    job_title  \
# 36        Data Analyst                                 Data Analyst
# 68        Data Analyst                    Sr. Research Data Analyst
# 68        Data Analyst                    Sr. Research Data Analyst
# 73        Data Analyst  Entry level / Systems Data Analyst (Remote)
# 73        Data Analyst  Entry level / Systems Data Analyst (Remote)
# ...                ...                                          ...
# 785685    Data Analyst                                 Data Analyst
# 785703    Data Analyst      Data Analyst - CRYPTOGRAPHY - Full-time
# 785705    Data Analyst    Expert Business Data Analyst - Now Hiring
# 785705    Data Analyst    Expert Business Data Analyst - Now Hiring
# 785705    Data Analyst    Expert Business Data Analyst - Now Hiring
#
#             job_location           job_via job_schedule_type  \
# 36        Des Moines, IA   via Trabajo.org         Full-time
# ...

# %%
df_pivot = df_da_US_explode.pivot_table(index='month',columns='job_skills', aggfunc='size', fill_value=0)
df_pivot
# Out:
# job_skills  airflow  airtable  alteryx  angular  ansible  apl  arch  asana  \
# month
# 1                39         7      206       21        7    1     0     15
# 2                35         0      203       23        4    1     0     14
# 3                39         1      219        5        5    6     1     14
# 4                28         1      208        8        3    7     3      5
# 5                27         3      144       15        8    9     1      5
# 6                39         5      188        9        4    8     3      7
# 7                42         2      160        5        3    5     5      6
# 8                44         2      187        5        3   10     0      5
# 9                22         3      145       11        2    3     4      4
# 10               29         9      144       13        2    0     3      2
# 11               23         1      126        4        2    0     1      2
# ...

# %%
# sorts by count
df_DA_US_pivot=df_pivot.copy()
df_DA_US_pivot.loc['Total'] = df_DA_US_pivot.sum()
df_DA_US_pivot = df_DA_US_pivot[df_DA_US_pivot.loc['Total'].sort_values(ascending=False).index]
df_DA_US_pivot = df_DA_US_pivot.drop('Total')

df_DA_US_pivot
# Out:
# job_skills   sql  excel  tableau  python   sas     r  power bi  word  \
# month
# 1           4601   3592     2488    2254  1832  1513      1337   968
# 2           3168   2587     1676    1618  1212  1045      1122   738
# 3           3226   2661     1804    1683  1238  1141      1054   736
# 4           3220   2549     1789    1679  1302  1038      1057   695
# 5           2581   2118     1432    1349   972   867       860   557
# 6           2862   2382     1628    1609   984  1017       989   721
# 7           2609   2118     1533    1438   996   881       881   587
# 8           3414   2731     1951    2025  1276  1271      1208   752
# 9           2295   1801     1353    1229   856   746       820   478
# 10          2574   1922     1429    1373   960   835       921   498
# 11          2054   1533     1148    1049   792   647       682   430
# 12          1848   1525     1080    1076   780   658       699   451
#
# ...

# %%
da_total = df_da_US.groupby('month').size()

# %%
df_perc = df_DA_US_pivot.div(da_total/100,axis = 0)
df_perc
# Out:
# job_skills        sql      excel    tableau     python        sas          r  \
# month
# 1           54.167648  42.288674  29.291264  26.536379  21.568166  17.812574
# 2           51.730895  42.243632  27.367734  26.420640  19.790986  17.064010
# 3           51.881634  42.795111  29.012544  27.066581  19.909939  18.349952
# 4           53.231939  42.139197  29.575136  27.756654  21.524219  17.159861
# 5           51.692369  42.419387  28.680152  27.017825  19.467254  17.364310
# 6           50.360725  41.914482  28.646841  28.312511  17.314799  17.895478
# 7           50.163430  40.722938  29.475101  27.648529  19.150163  16.939050
# 8           51.462165  41.166717  29.409105  30.524570  19.234248  19.158879
# 9           49.471869  38.823022  29.165768  26.492779  18.452253  16.081052
# 10          48.833238  36.463669  27.110605  26.048188  18.212863  15.841396
# 11          45.332156  33.833591  25.336570  23.151622  17.479585  14.279409
# ...

# %%
df_perc = df_perc.iloc[:,:5]
df_perc
# Out:
# job_skills        sql      excel    tableau     python        sas
# month
# 1           54.167648  42.288674  29.291264  26.536379  21.568166
# 2           51.730895  42.243632  27.367734  26.420640  19.790986
# 3           51.881634  42.795111  29.012544  27.066581  19.909939
# 4           53.231939  42.139197  29.575136  27.756654  21.524219
# 5           51.692369  42.419387  28.680152  27.017825  19.467254
# 6           50.360725  41.914482  28.646841  28.312511  17.314799
# 7           50.163430  40.722938  29.475101  27.648529  19.150163
# 8           51.462165  41.166717  29.409105  30.524570  19.234248
# 9           49.471869  38.823022  29.165768  26.492779  18.452253
# 10          48.833238  36.463669  27.110605  26.048188  18.212863
# 11          45.332156  33.833591  25.336570  23.151622  17.479585
# 12          46.443830  38.326213  27.142498  27.041970  19.602915

# %%
sns.lineplot(data = df_perc, dashes=False)
plt.title('Percentage of job skill trend')
plt.ylabel('Percentages')
# Out:
# Text(0, 0.5, 'Percentages')
