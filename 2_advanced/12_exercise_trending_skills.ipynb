# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt
import ast

dataset=load_dataset('lukebarousse/data_jobs')
df=dataset['train'].to_pandas()

df.job_posted_date=pd.to_datetime(df.job_posted_date)
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x )

# %%
df_da = df[df['job_title_short']== 'Data Analyst'].copy()
df_da.head()
# Out:
#    job_title_short                                          job_title  \
# 1     Data Analyst                                       Data Analyst
# 12    Data Analyst        Stagiaire Data Analyst (H/F) - Lyon (69006)
# 18    Data Analyst                                       Data Analyst
# 31    Data Analyst                           Stage - Data Analyst F/H
# 34    Data Analyst  Data Analyst als Marketing Manager Automation ...
#
#                     job_location                          job_via  \
# 1   Guadalajara, Jalisco, Mexico                 via BeBee México
# 12                  Lyon, France                     via Jobijoba
# 18                Warsaw, Poland            via Praca Trabajo.org
# 31                 Paris, France                     via LinkedIn
# 34             Erlangen, Germany  via Central Illinois Proud Jobs
#
#            job_schedule_type  job_work_from_home search_location  \
# 1                  Full-time               False          Mexico
# ...

# %%
df_da_explode = df_da.explode('job_skills').copy()
df_da_explode.head()
# Out:
#   job_title_short     job_title                  job_location  \
# 1    Data Analyst  Data Analyst  Guadalajara, Jalisco, Mexico
# 1    Data Analyst  Data Analyst  Guadalajara, Jalisco, Mexico
# 1    Data Analyst  Data Analyst  Guadalajara, Jalisco, Mexico
# 1    Data Analyst  Data Analyst  Guadalajara, Jalisco, Mexico
# 1    Data Analyst  Data Analyst  Guadalajara, Jalisco, Mexico
#
#             job_via job_schedule_type  job_work_from_home search_location  \
# 1  via BeBee México         Full-time               False          Mexico
# 1  via BeBee México         Full-time               False          Mexico
# 1  via BeBee México         Full-time               False          Mexico
# 1  via BeBee México         Full-time               False          Mexico
# 1  via BeBee México         Full-time               False          Mexico
#
#       job_posted_date  job_no_degree_mention  job_health_insurance  \
# 1 2023-01-14 13:18:07                  False                 False
# ...

# %%
df_da_explode['month'] = df_da_explode['job_posted_date'].dt.month
df_da_explode.sample()
# Out:
#        job_title_short                   job_title       job_location  \
# 560373    Data Analyst  Data Analyst - Urgent Hire  Stockholm, Sweden
#
#              job_via job_schedule_type  job_work_from_home search_location  \
# 560373  via GrabJobs         Full-time               False          Sweden
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 560373 2023-12-09 04:37:58                   True                 False
#
#        job_country salary_rate  salary_year_avg  salary_hour_avg company_name  \
# 560373      Sweden        None              NaN              NaN     Kisi Inc
#
#        job_skills                                    job_type_skills  month
# 560373        sql  {'analyst_tools': ['excel'], 'programming': ['...     12

# %%
df_pivot = df_da_explode.pivot_table(index='month', columns='job_skills', aggfunc='size', fill_value=0)
df_pivot.loc['Total'] =  df_pivot.sum()
df_pivot
# Out:
# job_skills  airflow  airtable  alteryx  angular  angular.js  ansible  apl  \
# month
# 1               197        17      551       63           2       20    2
# 2               169         2      448       49           0       14    1
# 3               181         4      442       34           0       23    6
# 4               155         4      413       22           0       11    8
# 5               128         8      310       30           0       19    9
# 6               164        14      393       29           0       14    9
# 7               207         4      366       15           0        8    5
# 8               197         3      413       21           0       12   10
# 9               118         4      317       21           0       14    3
# 10              173        11      350       40           0       19    0
# 11              169         7      293       24           0       19    0
# 12              144        10      274       28           0       13    0
# ...

# %%
df_pivot = df_pivot.sort_values(by='Total',axis=1,ascending=False)
df_pivot = df_pivot.iloc[:,:5].drop('Total')

# %%
df_pivot
# Out:
# job_skills    sql  excel  python  tableau  power bi
# month
# 1           11336   8170    6606     5596      4285
# 2            7947   5772    4751     3936      3307
# 3            7868   5675    4741     4051      3176
# 4            7553   5496    4557     3776      3106
# 5            6617   4773    4070     3245      2695
# 6            7584   5724    4707     3812      3275
# 7            7687   5513    4831     3928      3350
# 8            8823   6482    5576     4533      3859
# 9            6829   4886    4229     3446      3118
# 10           7474   5217    4693     3709      3340
# 11           6652   4776    4233     3284      3012
# 12           6058   4376    4196     3139      2857

# %%
df_pivot.plot(kind='line')
plt.title('Top 5 skill trending line for Data Analyst')
plt.xlabel('Months')
plt.ylabel('count')
plt.show()
