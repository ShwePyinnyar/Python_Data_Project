# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

dataset=load_dataset('lukebarousse/data_jobs')
df=dataset['train'].to_pandas()

df.job_posted_date=pd.to_datetime(df.job_posted_date)

# %%
df_salary = df[df['salary_year_avg'].notna()].copy()
df_salary
# Out:
#        job_title_short                                          job_title  \
# 28      Data Scientist                                CRM Data Specialist
# 77       Data Engineer                                      Data Engineer
# 92       Data Engineer            Remote - Data Engineer - Permanent - W2
# 100     Data Scientist            Data Scientist, Risk Data Mining - USDS
# 109       Data Analyst              Senior Supply Chain Analytics Analyst
# ...                ...                                                ...
# 785624   Data Engineer                   Data Analytics Engineer (Hybrid)
# 785641   Data Engineer                                      Data Engineer
# 785648  Data Scientist  Director Data Scientist - Commercial Platforms...
# 785682  Data Scientist  Data Scientist für datengetriebene Entwicklung...
# 785692  Data Scientist               Data Scientist- Hybrid Work Location
#
#                                    job_location          job_via  \
# 28      San José Province, San José, Costa Rica  via Ai-Jobs.net
# 77                                Arlington, VA     via LinkedIn
# 92                                     Anywhere     via LinkedIn
# 100                           Mountain View, CA     via LinkedIn
# 109                                    Anywhere       via Get.It
# ...                                         ...              ...
# 785624                          Mt Prospect, IL  via Ai-Jobs.net
# 785641                             New York, NY         via Dice
# 785648                        Pleasant Hill, CA  via Ai-Jobs.net
# 785682                      Reutlingen, Germany  via Ai-Jobs.net
# 785692                               Dayton, OH  via Ai-Jobs.net
#
#        job_schedule_type  job_work_from_home            search_location  \
# 28             Full-time               False                 Costa Rica
# 77             Full-time               False                      Sudan
# 92             Full-time                True    Illinois, United States
# 100            Full-time               False  California, United States
# 109            Full-time                True    Illinois, United States
# ...                  ...                 ...                        ...
# 785624         Full-time               False    Illinois, United States
# 785641         Full-time               False                    Georgia
# 785648         Full-time               False  California, United States
# 785682         Full-time               False                    Germany
# 785692         Full-time               False    Illinois, United States
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 28     2023-08-01 13:37:57                  False                 False
# 77     2023-06-26 14:22:54                  False                 False
# 92     2023-02-21 13:29:59                  False                  True
# 100    2023-07-31 13:01:18                  False                  True
# 109    2023-10-12 13:02:19                  False                  True
# ...                    ...                    ...                   ...
# 785624 2023-08-31 06:02:16                  False                  True
# 785641 2023-01-04 16:36:07                   True                 False
# 785648 2023-04-12 06:02:51                  False                  True
# 785682 2023-03-04 06:16:08                  False                 False
# 785692 2023-04-21 06:02:31                  False                  True
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 28         Costa Rica        year         109500.0              NaN
# 77              Sudan        year         140000.0              NaN
# 92      United States        year         120000.0              NaN
# 100     United States        year         228222.0              NaN
# 109     United States        year          89000.0              NaN
# ...               ...         ...              ...              ...
# 785624  United States        year         139216.0              NaN
# 785641  United States        year         150000.0              NaN
# 785648  United States        year         221875.0              NaN
# 785682        Germany        year         157500.0              NaN
# 785692  United States        year         157500.0              NaN
#
#                            company_name  \
# 28                             Netskope
# 77                           Intelletec
# 92                         Apex Systems
# 100                              TikTok
# 109     Get It Recruit - Transportation
# ...                                 ...
# 785624                      Bosch Group
# 785641            Engage Partners, Inc.
# 785648                           84.51°
# 785682                      Bosch Group
# 785692                           Tenet3
#
#                                                job_skills  \
# 28                                      ['gdpr', 'excel']
# 77      ['mongodb', 'mongodb', 'python', 'r', 'sql', '...
# 92                                      ['sql', 'python']
# 100                     ['sql', 'r', 'python', 'express']
# 109                 ['python', 'r', 'alteryx', 'tableau']
# ...                                                   ...
# 785624  ['go', 'python', 'r', 'sql', 'oracle', 'window...
# 785641                                               None
# 785648          ['python', 'azure', 'snowflake', 'spark']
# 785682  ['python', 'hadoop', 'spark', 'airflow', 'kube...
# 785692                          ['python', 'matlab', 'r']
#
#                                           job_type_skills
# 28      {'analyst_tools': ['excel'], 'libraries': ['gd...
# 77      {'analyst_tools': ['tableau'], 'cloud': ['orac...
# 92                     {'programming': ['sql', 'python']}
# 100     {'programming': ['sql', 'r', 'python'], 'webfr...
# 109     {'analyst_tools': ['alteryx', 'tableau'], 'pro...
# ...                                                   ...
# 785624  {'analyst_tools': ['alteryx', 'power bi', 'tab...
# 785641                                               None
# 785648  {'cloud': ['azure', 'snowflake'], 'libraries':...
# 785682  {'libraries': ['hadoop', 'spark', 'airflow'], ...
# 785692         {'programming': ['python', 'matlab', 'r']}
#
# [22003 rows x 17 columns]

# %%
df_salary['salary_year_inflated'] = df_salary['salary_year_avg'].apply(lambda x: x*1.03)
df_salary[['salary_year_inflated','salary_year_avg']]
# Out:
#         salary_year_inflated  salary_year_avg
# 28                 112785.00         109500.0
# 77                 144200.00         140000.0
# 92                 123600.00         120000.0
# 100                235068.66         228222.0
# 109                 91670.00          89000.0
# ...                      ...              ...
# 785624             143392.48         139216.0
# 785641             154500.00         150000.0
# 785648             228531.25         221875.0
# 785682             162225.00         157500.0
# 785692             162225.00         157500.0
#
# [22003 rows x 2 columns]

# %%
import ast

# %%
def clean_list(skill_list):
    if pd.notna(skill_list):
        return ast.literal_eval(skill_list)
df['job_skills'] = df['job_skills'].apply(clean_list)

# %%
type(df['job_skills'][1])
# Out:
# list

# %%
df[df['job_skills'].notna()]
# Out:
#           job_title_short                                          job_title  \
# 1            Data Analyst                                       Data Analyst
# 2           Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3           Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4           Data Engineer                             Data Engineer- Sr Jobs
# 5           Data Engineer                                  GCP Data Engineer
# ...                   ...                                                ...
# 785736  Software Engineer                                    DevOps Engineer
# 785737       Data Analyst                                   CRM Data Analyst
# 785738   Business Analyst                     Commercial Analyst - Start Now
# 785739      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 785740  Software Engineer                                 AWS System Analyst
#
#                                job_location                    job_via  \
# 1              Guadalajara, Jalisco, Mexico           via BeBee México
# 2                           Berlin, Germany               via LinkedIn
# 3                           San Antonio, TX          via Diversity.com
# 4                            Washington, DC         via Clearance Jobs
# 5                                  Anywhere           via ZipRecruiter
# ...                                     ...                        ...
# 785736                            Singapura        melalui Trabajo.org
# 785737                   Bad Rodach, Jerman  melalui BeBee Deutschland
# 785738                             Malaysia           melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785740                                India             melalui Trigyn
#
#                job_schedule_type  job_work_from_home       search_location  \
# 1                      Full-time               False                Mexico
# 2                      Full-time               False               Germany
# 3                      Full-time               False  Texas, United States
# 4                      Full-time               False                 Sudan
# 5       Contractor and Temp work                True               Georgia
# ...                          ...                 ...                   ...
# 785736           Pekerjaan tetap               False             Singapore
# 785737           Pekerjaan tetap               False               Germany
# 785738           Pekerjaan tetap               False              Malaysia
# 785739           Pekerjaan tetap               False                 Sudan
# 785740           Pekerjaan tetap               False                 India
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 1      2023-01-14 13:18:07                  False                 False
# 2      2023-10-10 13:14:55                  False                 False
# 3      2023-07-04 13:01:41                   True                 False
# 4      2023-08-07 14:29:36                  False                 False
# 5      2023-11-07 14:01:59                  False                 False
# ...                    ...                    ...                   ...
# 785736 2023-03-13 06:16:16                  False                 False
# 785737 2023-03-12 06:18:18                  False                 False
# 785738 2023-03-12 06:32:36                  False                 False
# 785739 2023-03-12 06:32:15                  False                 False
# 785740 2023-03-13 06:16:31                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 1              Mexico        None              NaN              NaN
# 2             Germany        None              NaN              NaN
# 3       United States        None              NaN              NaN
# 4               Sudan        None              NaN              NaN
# 5       United States        None              NaN              NaN
# ...               ...         ...              ...              ...
# 785736      Singapore        None              NaN              NaN
# 785737        Germany        None              NaN              NaN
# 785738       Malaysia        None              NaN              NaN
# 785739          Sudan        None              NaN              NaN
# 785740          India        None              NaN              NaN
#
#                               company_name  \
# 1               Hewlett Packard Enterprise
# 2                 ALPHA Augmented Services
# 3             Southwest Research Institute
# 4                          Kristina Daniel
# 5                          smart folks inc
# ...                                    ...
# 785736  CAREERSTAR INTERNATIONAL PTE. LTD.
# 785737                    HABA FAMILYGROUP
# 785738               Lendlease Corporation
# 785739                         Capital One
# 785740                              Trigyn
#
#                                                job_skills  \
# 1              [r, python, sql, nosql, power bi, tableau]
# 2       [python, sql, c#, azure, airflow, dax, docker,...
# 3       [python, c++, java, matlab, aws, tensorflow, k...
# 4       [bash, python, oracle, aws, ansible, puppet, j...
# 5                                      [python, sql, gcp]
# ...                                                   ...
# 785736  [bash, python, perl, linux, unix, kubernetes, ...
# 785737                             [sas, sas, sql, excel]
# 785738                                [powerpoint, excel]
# 785739  [python, go, nosql, sql, mongo, shell, mysql, ...
# 785740                                        [aws, flow]
#
#                                           job_type_skills
# 1       {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2       {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3       {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4       {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
# 5       {'cloud': ['gcp'], 'programming': ['python', '...
# ...                                                   ...
# 785736  {'os': ['linux', 'unix'], 'other': ['kubernete...
# 785737  {'analyst_tools': ['sas', 'excel'], 'programmi...
# 785738         {'analyst_tools': ['powerpoint', 'excel']}
# 785739  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# 785740              {'cloud': ['aws'], 'other': ['flow']}
#
# [668704 rows x 17 columns]

# %%
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
type(df['job_skills'][1])
# Out:
# list

# %%
df_salary.head()
# Out:
#     job_title_short                                job_title  \
# 28   Data Scientist                      CRM Data Specialist
# 77    Data Engineer                            Data Engineer
# 92    Data Engineer  Remote - Data Engineer - Permanent - W2
# 100  Data Scientist  Data Scientist, Risk Data Mining - USDS
# 109    Data Analyst    Senior Supply Chain Analytics Analyst
#
#                                 job_location          job_via  \
# 28   San José Province, San José, Costa Rica  via Ai-Jobs.net
# 77                             Arlington, VA     via LinkedIn
# 92                                  Anywhere     via LinkedIn
# 100                        Mountain View, CA     via LinkedIn
# 109                                 Anywhere       via Get.It
#
#     job_schedule_type  job_work_from_home            search_location  \
# 28          Full-time               False                 Costa Rica
# 77          Full-time               False                      Sudan
# 92          Full-time                True    Illinois, United States
# 100         Full-time               False  California, United States
# 109         Full-time                True    Illinois, United States
#
#         job_posted_date  job_no_degree_mention  job_health_insurance  \
# 28  2023-08-01 13:37:57                  False                 False
# 77  2023-06-26 14:22:54                  False                 False
# 92  2023-02-21 13:29:59                  False                  True
# 100 2023-07-31 13:01:18                  False                  True
# 109 2023-10-12 13:02:19                  False                  True
#
#        job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 28      Costa Rica        year         109500.0              NaN
# 77           Sudan        year         140000.0              NaN
# 92   United States        year         120000.0              NaN
# 100  United States        year         228222.0              NaN
# 109  United States        year          89000.0              NaN
#
#                         company_name  \
# 28                          Netskope
# 77                        Intelletec
# 92                      Apex Systems
# 100                           TikTok
# 109  Get It Recruit - Transportation
#
#                                             job_skills  \
# 28                                   ['gdpr', 'excel']
# 77   ['mongodb', 'mongodb', 'python', 'r', 'sql', '...
# 92                                   ['sql', 'python']
# 100                  ['sql', 'r', 'python', 'express']
# 109              ['python', 'r', 'alteryx', 'tableau']
#
#                                        job_type_skills  salary_year_inflated
# 28   {'analyst_tools': ['excel'], 'libraries': ['gd...             112785.00
# 77   {'analyst_tools': ['tableau'], 'cloud': ['orac...             144200.00
# 92                  {'programming': ['sql', 'python']}             123600.00
# 100  {'programming': ['sql', 'r', 'python'], 'webfr...             235068.66
# 109  {'analyst_tools': ['alteryx', 'tableau'], 'pro...              91670.00

# %%
def projected_salary(row):
    if 'Senior' in row['job_title_short']:
        return 1.05 * row['salary_year_avg']
    else:
        return 1.03 * row['salary_year_avg']
    
df_salary['new_salary'] = df_salary.apply(projected_salary, axis=1)

df_salary.sample(10)
# Out:
#                   job_title_short  \
# 336599              Data Engineer
# 425955             Data Scientist
# 9143               Data Scientist
# 692709              Data Engineer
# 380870        Senior Data Analyst
# 445396  Machine Learning Engineer
# 169908              Data Engineer
# 115594              Data Engineer
# 142420       Senior Data Engineer
# 127028               Data Analyst
#
#                                                 job_title  \
# 336599                                   Sr Data Engineer
# 425955                                     Data Scientist
# 9143                               Manager - Data Science
# 692709                      Lead Data Engineer with Azure
# 380870  Senior Analyst - Adobe Analytics Implementatio...
# 445396                Machine Learning Research Scientist
# 169908                     Data Engineer - Risk Analytics
# 115594                      Azure Data Architect/Engineer
# 142420                               Senior Data Engineer
# 127028                                     Data Analyst V
#
#                        job_location                   job_via  \
# 336599             Santa Monica, CA           via ShowbizJobs
# 425955                     Anywhere                via Indeed
# 9143    Bengaluru, Karnataka, India           via Ai-Jobs.net
# 692709                  Newtown, PA               via Ladders
# 380870                   Dallas, TX  via My Valley Jobs Today
# 445396                         None           via Ai-Jobs.net
# 169908                     Anywhere              via LinkedIn
# 115594          Anderlecht, Belgium           via Ai-Jobs.net
# 142420                  Atlanta, GA               via Ladders
# 127028               Menlo Park, CA               via Ladders
#
#        job_schedule_type  job_work_from_home            search_location  \
# 336599         Full-time               False                    Georgia
# 425955         Full-time                True       Texas, United States
# 9143           Full-time               False                      India
# 692709         Full-time               False                    Georgia
# 380870         Full-time               False       Texas, United States
# 445396         Full-time               False                South Korea
# 169908         Full-time                True  California, United States
# 115594         Full-time               False                    Belgium
# 142420         Full-time               False                      Sudan
# 127028         Full-time               False  California, United States
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 336599 2023-07-27 23:56:35                  False                  True
# 425955 2023-10-23 16:02:19                  False                  True
# 9143   2023-05-12 13:28:49                  False                 False
# 692709 2023-04-12 11:02:19                   True                  True
# 380870 2023-11-04 18:01:28                  False                 False
# 445396 2023-07-20 16:52:43                  False                 False
# 169908 2023-02-07 15:06:43                   True                  True
# 115594 2023-06-22 08:55:14                  False                 False
# 142420 2023-04-26 09:38:04                  False                  True
# 127028 2023-11-19 08:00:24                  False                  True
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 336599  United States        year         163500.0              NaN
# 425955  United States        year         105000.0              NaN
# 9143            India        year          79200.0              NaN
# 692709  United States        year          90000.0              NaN
# 380870  United States        year         102500.0              NaN
# 445396    South Korea        year          79200.0              NaN
# 169908  United States        year         112500.0              NaN
# 115594        Belgium        year          89100.0              NaN
# 142420          Sudan        year          90000.0              NaN
# 127028  United States        year         101014.0              NaN
#
#                  company_name  \
# 336599                 Disney
# 425955              SportsBiz
# 9143                    BitGo
# 692709           EPAM Systems
# 380870       Publicis Sapient
# 445396            Match Group
# 169908  Elsdon Consulting ltd
# 115594                   Ypto
# 142420   Clarkston Consulting
# 127028         Insight Global
#
#                                                job_skills  \
# 336599                           ['elasticsearch', 'aws']
# 425955  ['python', 'aws', 'numpy', 'pandas', 'scikit-l...
# 9143                                   ['sql', 'tableau']
# 692709  ['python', 'scala', 'sql', 'java', 'azure', 'd...
# 380870  ['javascript', 'html', 'css', 'python', 'jquer...
# 445396                                       ['bigquery']
# 169908                  ['sql', 'python', 'r', 'tableau']
# 115594  ['sql', 'c#', 'sql server', 'azure', 'databric...
# 142420  ['sql', 'scala', 'python', 'java', 'c++', 'dat...
# 127028                 ['powerpoint', 'excel', 'tableau']
#
#                                           job_type_skills  \
# 336599  {'cloud': ['aws'], 'databases': ['elasticsearc...
# 425955  {'cloud': ['aws'], 'libraries': ['numpy', 'pan...
# 9143    {'analyst_tools': ['tableau'], 'programming': ...
# 692709  {'cloud': ['azure', 'databricks'], 'programmin...
# 380870  {'other': ['flow'], 'programming': ['javascrip...
# 445396                            {'cloud': ['bigquery']}
# 169908  {'analyst_tools': ['tableau'], 'programming': ...
# 115594  {'cloud': ['azure', 'databricks', 'aws'], 'dat...
# 142420  {'cloud': ['databricks', 'snowflake', 'azure',...
# 127028  {'analyst_tools': ['powerpoint', 'excel', 'tab...
#
#         salary_year_inflated  new_salary
# 336599             168405.00   168405.00
# 425955             108150.00   108150.00
# 9143                81576.00    81576.00
# 692709              92700.00    92700.00
# 380870             105575.00   107625.00
# 445396              81576.00    81576.00
# 169908             115875.00   115875.00
# 115594              91773.00    91773.00
# 142420              92700.00    94500.00
# 127028             104044.42   104044.42
