# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt
import ast

dataset=load_dataset('lukebarousse/data_jobs')
df=dataset['train'].to_pandas()

df.job_posted_date=pd.to_datetime(df.job_posted_date)
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x )

df_da = df[df['job_title_short'] == 'Data Analyst']

# %%
df_DA_US = df[(df['job_title_short'] == 'Data Analyst') & (df['job_country'] == 'United States')].copy()
df_DA_US.sample()
# Out:
#        job_title_short                                          job_title  \
# 165481    Data Analyst  "_Ops Risk Data Analyst - Hybrid (Max $28/hr W...
#
#          job_location       job_via job_schedule_type  job_work_from_home  \
# 165481  Baltimore, MD  via LinkedIn        Contractor               False
#
#                 search_location     job_posted_date  job_no_degree_mention  \
# 165481  New York, United States 2023-03-01 15:00:32                  False
#
#         job_health_insurance    job_country salary_rate  salary_year_avg  \
# 165481                 False  United States        None              NaN
#
#         salary_hour_avg company_name    job_skills  \
# 165481              NaN         Dice  [sql, excel]
#
#                                           job_type_skills
# 165481  {'analyst_tools': ['excel'], 'programming': ['...

# %%
df_DA_US['salary_year_avg'].plot(kind='box', vert=False)
# Out:
# <Axes: >

# %%
job_titles = ['Data Analyst','Data Engineer','Data Scientist']

df_US = df[(df['job_title_short'].isin(job_titles)) & (df['job_country'] == 'United States')].copy()
df_US.sample(5)
# Out:
#        job_title_short                                        job_title  \
# 729069  Data Scientist                      Remote Staff Data Scientist
# 285636  Data Scientist                     Manufacturing Data Scientist
# 241284   Data Engineer  Sr. Manager - Data Engineer (San Francisco, CA)
# 205965   Data Engineer                                    Data Engineer
# 723125   Data Engineer                                    Data Engineer
#
#              job_location                     job_via job_schedule_type  \
# 729069           Anywhere                via LinkedIn         Full-time
# 285636        Atlanta, GA            via ZipRecruiter         Full-time
# 241284  San Francisco, CA  via Built In San Francisco         Full-time
# 205965      United States                via LinkedIn         Full-time
# 723125         Boston, MA                   via Lensa         Full-time
#
#         job_work_from_home            search_location     job_posted_date  \
# 729069                True  California, United States 2023-05-16 21:03:22
# 285636               False                    Georgia 2023-01-01 18:17:39
# 241284               False    New York, United States 2023-02-03 07:08:57
# 205965               False    New York, United States 2023-11-17 22:06:08
# 723125               False    New York, United States 2023-04-03 21:08:15
#
#         job_no_degree_mention  job_health_insurance    job_country  \
# 729069                  False                 False  United States
# 285636                  False                  True  United States
# 241284                  False                  True  United States
# 205965                  False                 False  United States
# 723125                  False                 False  United States
#
#        salary_rate  salary_year_avg  salary_hour_avg         company_name  \
# 729069        None              NaN              NaN      RemoteWorker US
# 285636        None              NaN              NaN  International Paper
# 241284        None              NaN              NaN          Capital One
# 205965        None              NaN              NaN        Relate Search
# 723125        None              NaN              NaN  Explore Jobs Search
#
#                                                job_skills  \
# 729069              [python, sql, aws, gcp, azure, spark]
# 285636   [sql, r, python, matlab, sap, tableau, power bi]
# 241284  [java, scala, python, nosql, sql, mongo, shell...
# 205965  [python, java, scala, sql, aws, azure, gcp, ha...
# 723125  [nosql, bash, python, perl, golang, ruby, ruby...
#
#                                           job_type_skills
# 729069  {'cloud': ['aws', 'gcp', 'azure'], 'libraries'...
# 285636  {'analyst_tools': ['sap', 'tableau', 'power bi...
# 241284  {'cloud': ['redshift', 'snowflake', 'aws', 'az...
# 205965  {'cloud': ['aws', 'azure', 'gcp'], 'libraries'...
# 723125  {'cloud': ['aws', 'aurora', 'redshift', 'snowf...

# %%
df_US=df_US.dropna(subset='salary_year_avg')
df_US.head()
# Out:
#     job_title_short                                          job_title  \
# 92    Data Engineer            Remote - Data Engineer - Permanent - W2
# 100  Data Scientist            Data Scientist, Risk Data Mining - USDS
# 109    Data Analyst              Senior Supply Chain Analytics Analyst
# 116  Data Scientist                                     Data Scientist
# 146   Data Engineer  Data Engineer Graduate (Real Time Communicatio...
#
#           job_location       job_via job_schedule_type  job_work_from_home  \
# 92            Anywhere  via LinkedIn         Full-time                True
# 100  Mountain View, CA  via LinkedIn         Full-time               False
# 109           Anywhere    via Get.It         Full-time                True
# 116           Anywhere  via LinkedIn         Full-time                True
# 146        Seattle, WA  via LinkedIn         Full-time               False
#
#                search_location     job_posted_date  job_no_degree_mention  \
# 92     Illinois, United States 2023-02-21 13:29:59                  False
# 100  California, United States 2023-07-31 13:01:18                  False
# 109    Illinois, United States 2023-10-12 13:02:19                  False
# 116       Texas, United States 2023-10-04 13:04:23                  False
# 146  California, United States 2023-10-21 13:06:16                  False
#
#      job_health_insurance    job_country salary_rate  salary_year_avg  \
# 92                   True  United States        year         120000.0
# 100                  True  United States        year         228222.0
# 109                  True  United States        year          89000.0
# 116                 False  United States        year         114000.0
# 146                  True  United States        year         129500.0
#
#      salary_hour_avg                     company_name  \
# 92               NaN                     Apex Systems
# 100              NaN                           TikTok
# 109              NaN  Get It Recruit - Transportation
# 116              NaN               4 Corner Resources
# 146              NaN                        ByteDance
#
#                                           job_skills  \
# 92                                     [sql, python]
# 100                        [sql, r, python, express]
# 109                    [python, r, alteryx, tableau]
# 116  [r, python, sql, t-sql, hadoop, spark, tableau]
# 146     [golang, scala, python, java, hadoop, spark]
#
#                                        job_type_skills
# 92                  {'programming': ['sql', 'python']}
# 100  {'programming': ['sql', 'r', 'python'], 'webfr...
# 109  {'analyst_tools': ['alteryx', 'tableau'], 'pro...
# 116  {'analyst_tools': ['tableau'], 'libraries': ['...
# 146  {'libraries': ['hadoop', 'spark'], 'programmin...

# %%
df_US.pivot(columns='job_title_short', values='salary_year_avg').plot(kind='box', vert=False)
# Out:
# <Axes: >

# %%
df_US.boxplot(column='salary_year_avg',by='job_title_short',vert=False)
ax = plt.gca()
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, pos:f'${int(x/1000)}K'))
plt.xlim(0,600000)
# Out:
# (0.0, 600000.0)
